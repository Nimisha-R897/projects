# %%
#training--------
#1.Load the DATA (excel sheet)
import pandas as pd
file=pd.read_csv("/content/13 MLP winequality-red.csv")
x=file[["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"]]
y=file["quality"]

#Cross validation
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

#2.Load the MODEL(MLPClassifier)
from sklearn.neural_network import MLPClassifier
a1=MLPClassifier(hidden_layer_sizes=(5,))
a2=MLPClassifier(hidden_layer_sizes=(15,6))
a3=MLPClassifier(hidden_layer_sizes=(35,10))
a4=MLPClassifier(hidden_layer_sizes=(17,6,2))
a5=MLPClassifier(hidden_layer_sizes=(13,))

#3.Fit DATA into MODEL
a1.fit(xtrain,ytrain)
a2.fit(xtrain,ytrain)
a3.fit(xtrain,ytrain)
a4.fit(xtrain,ytrain)
a5.fit(xtrain,ytrain)
#validation
op1=a1.predict(xtest)
op2=a2.predict(xtest)
op3=a3.predict(xtest)
op4=a4.predict(xtest)
op5=a5.predict(xtest)

from sklearn.metrics import accuracy_score
score1=accuracy_score(ytest,op1)
score2=accuracy_score(ytest,op2)
score3=accuracy_score(ytest,op3)
score4=accuracy_score(ytest,op4)
score5=accuracy_score(ytest,op5)
print("accuracy1=",score1*100)
print("accuracy2=",score2*100)
print("accuracy3=",score3*100)
print("accuracy4=",score4*100)
print("accuracy5=",score5*100)

#Testing--------predict
result1=a1.predict([[7.8,0.88,5.8,8.5,4.5,5.5,6.9,8.1,6.4,7.5,8.7]])
result2=a2.predict([[2.2,9.4,3.4,6.8,4.8,4.2,1.9,6.3,9.5,10,0.007]])
result3=a3.predict([[2.5,0.007,5.7,8.2,4.6,5.4,0.002,0.003,5.34,7.12,0.008]])
result4=a4.predict([[2.6,0.008,5.2,8.5,4.7,5.1,0.006,0.009,5.45,7.38,0.005]])
result5=a5.predict([[2.8,0.07,5.47,8.62,4.67,5.24,0.007,0.004,5.12,7.10,0.003]])
print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# accuracy1= 51.24999999999999
# accuracy2= 50.31250000000001
# ...

# %%
#training--------
#1.Load the DATA (excel sheet)
import pandas as pd
file=pd.read_csv("/content/13 MLP winequality-red.csv")
x=file[["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"]]
y=file["quality"]

#Cross validation
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

#2.Load the MODEL(MLPClassifier)
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
architectures=[
    (5,),
    (10,),
    (20,),
    (10,10),
    (20,10),
]
for i in architectures:
  a=MLPClassifier(hidden_layer_sizes=i)
  a.fit(xtrain,ytrain)
  op=a.predict(xtest)
  score=accuracy_score(ytest,op)
  print("accuracy=",score*100)
  result=a.predict([[7.8,0.88,5.8,8.5,4.5,5.5,6.9,8.1,6.4,7.5,8.7]])
  print(result)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(
# accuracy= 52.1875
# [6]
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(
# accuracy= 50.31250000000001
# [6]
# ...

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(ytest,op)
print(cm)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,
                           display_labels=a.classes_)
cmd.plot()
# Out:
# [[  0   0   3   0   0   0]
#  [  0   0  11   2   0   0]
#  [  0   0 113  30   0   0]
#  [  0   0  45  74   0   0]
#  [  0   0   4  32   2   0]
#  [  0   0   0   3   1   0]]

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm1 = confusion_matrix(ytest,op1)
cm2 = confusion_matrix(ytest,op2)
cm3 = confusion_matrix(ytest,op3)
print(cm1)
print(cm2)
print(cm3)

cmd1=ConfusionMatrixDisplay(confusion_matrix=cm1,
                           display_labels=a1.classes_)
cmd2=ConfusionMatrixDisplay(confusion_matrix=cm2,
                           display_labels=a2.classes_)
cmd3=ConfusionMatrixDisplay(confusion_matrix=cm3,
                           display_labels=a3.classes_)
cmd1.plot()
cmd2.plot()
cmd3.plot()
# Out:
# [[ 0  0  2  1  0  0]
#  [ 0  0  8  3  0  0]
#  [ 0  0 90 47  0  0]
#  [ 0  0 38 86  0  0]
#  [ 0  0  6 34  0  0]
#  [ 0  0  0  5  0  0]]
# [[  0   0   3   0   0   0]
#  [  0   0   9   2   0   0]
#  [  0   0 101  36   0   0]
#  [  0   0  40  73  11   0]
#  [  0   0   4  28   8   0]
#  [  0   0   0   2   3   0]]
# [[ 0  0  3  0  0  0]
#  [ 0  0  6  5  0  0]
#  [ 0  0 66 70  1  0]
#  [ 0  0 21 96  7  0]
#  [ 0  0  2 28 10  0]
#  [ 0  0  0  3  2  0]]

# %%
import pandas as pd
file=pd.read_csv("/content/13 MLP winequality-red.csv")
print(file)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...
